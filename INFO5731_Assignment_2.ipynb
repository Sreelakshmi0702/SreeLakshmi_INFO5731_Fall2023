# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreelakshmi0702/SreeLakshmi_INFO5731_Fall2023/blob/main/INFO5731_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon.
#
# (2) Collect the top 10000 User Reviews of a film recently in 2023 or 2022 (you can choose any film) from IMDB.
#
# (3) Collect all the reviews of the top 1000 most popular software from [G2](https://www.g2.com/) or [Capterra](https://www.capterra.com/)
#
# (4) Collect the abstracts of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from [Semantic Scholar](https://www.semanticscholar.org).
#
# (5) Collect all the information of the 904 narrators in the [Densho Digital Repository](https://ddr.densho.org/narrators/).
#
# (6) Collect the top 10000 reddits by using a hashtag (you can use any hashtag) from Reddits.

# %%
# Write your code here


from bs4 import BeautifulSoup
import requests
import pandas as pd
from IPython.display import clear_output

base_url = "https://www.amazon.in/Apple-iPhone-11-128GB-Black/product-reviews/B07XVLW7YK/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber="
Reviewer = list()
Rating = list()
Review_Summary = list()
Review_Description = list()
for i in range(1, 1001):
  response = requests.get(base_url+str(i))
  soup = BeautifulSoup(response.text, 'html.parser')
  Name = soup.findAll("span", {"class" : "a-profile-name"})
  for i in range(5, len(Name)):
      Reviewer.append(Name[i].get_text())
  Product_Rating = soup.findAll("i", {"class" : "review-rating"})
  for i in range(2, len(Product_Rating)):
    Rating.append(float(Product_Rating[i].get_text().split()[0]))
  Review_Title = soup.findAll("a", {"class" : "review-title-content"})
  for i in range(0, len(Review_Title)):
    Review_Summary.append(Review_Title[i].get_text())
  Description = soup.findAll("span", {"class" : "review-text-content"})
  for i in range(0, len(Description)):
    Review_Description.append(Description[i].get_text())
  clear_output()
  print(f"processed {i}th page")
Reviewer += ["Amazon Customer" for _ in range(len(Review_Description)-len(Reviewer))]

df = pd.DataFrame({
  "Reviewer": Reviewer,
  "Rating": Rating,
  "Summary": Review_Summary,
  "Description": Review_Description
})

df.to_csv(r'reviews.csv', index= 'True')

df
# Out:
# processed 1000th page
#                  Reviewer  Rating  \
# 0            Sombir Kumar     4.0
# 1               Suresh g.     5.0
# 2                     Sam     4.0
# 3              priyesh j.     5.0
# 4                  pk2013     5.0
# 5                      PR     5.0
# 6                      PR     4.0
# 7                     MSA     5.0
# 8  ronit pareshbhai badal     4.0
# 9         Amazon Customer     5.0
#
#                                              Summary  \
# 0             4.0 out of 5 stars\niPhone 11 review\n
# 1            5.0 out of 5 stars\nLove my iPhone ❤️\n
# 2                    4.0 out of 5 stars\nExcellent\n
# 3               5.0 out of 5 stars\nGreat Purchase\n
# 4    5.0 out of 5 stars\nMy buddy for last 3 years\n
# 5                5.0 out of 5 stars\nAwesome Phone\n
# 6            4.0 out of 5 stars\nBeast with a limp\n
# 7  5.0 out of 5 stars\nThe best iPhone - perfect ...
# 8  4.0 out of 5 stars\nSo far so good...(1 week u...
# 9   5.0 out of 5 stars\nIphones dont need a review\n
#
#                                          Description
# 0  \niPhone11 Review A person who uses every majo...
# 1  \nSorry for giving a late feedback.It has alre...
# 2                                      \nExcellent\n
# 3  \nI think it's better to buy a little expensiv...
# 4  \nI used it the worst way one ever ; gaming wi...
# 5  \n\n\n\n\n                    The media could ...
# 6  \nBeen almost 10 months I have been using the ...
# 7  \nThis is my first iPhone. After being an Andr...
# 8  \nI am a first time and new iphone user after ...
# 9  \nIphone is always best, but with amazon I ass...

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write your code here
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
#before cleaning
print("Before Cleaning.\n", df.Description.head(), end="\n\n")

#1
df.Description = df.Description.str.replace('[^\w\s]','')
print("(1) Remove noise, such as special characters and punctuations.\n", df.Description.head(), end="\n\n")

#2
df.Description = df.Description.str.replace('\d+','')
print("(2) Remove numbers.\n", df.Description.head(), end="\n\n")

#3
import requests
response = requests.get("https://gist.githubusercontent.com/sebleier/554280/raw/7e0e4a1ce04c2bb7bd41089c9821dbcf6d0c786c/NLTK's%2520list%2520of%2520english%2520stopwords")
stopwords = [word for word in response.text.replace('\n', ' ').split()]
df.Description = df.Description.apply(lambda sent: " ".join((word for word in sent.split() if word.lower() not in stopwords)))
print("(3) Remove stopwords by using the stopwords list.\n", df.Description.head(), end="\n\n")

#4
df.Description = df.Description.apply(lambda sent: sent.lower())
print("(4) Lowercase all texts.\n", df.Description.head(), end="\n\n")

#5
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
df.Description.apply(lambda sent: " ".join([stemmer.stem(word) for word in sent.split()]))
print("(5) Stemming.\n", df.Description.head(), end="\n\n")

#6
from textblob import Word
import nltk
nltk.download('wordnet')
df.Description = df.Description.apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
print("(6) Lemmatization.\n", df.Description.head(), end="\n\n")
# Out:
# Before Cleaning.
#  0    \niPhone11 Review A person who uses every majo...
# 1    \nSorry for giving a late feedback.It has alre...
# 2                                        \nExcellent\n
# 3    \nI think it's better to buy a little expensiv...
# 4    \nI used it the worst way one ever ; gaming wi...
# Name: Description, dtype: object
#
# (1) Remove noise, such as special characters and punctuations.
#  0    \niPhone11 Review A person who uses every majo...
# 1    \nSorry for giving a late feedbackIt has alrea...
# 2                                        \nExcellent\n
# 3    \nI think its better to buy a little expensive...
# 4    \nI used it the worst way one ever  gaming wit...
# Name: Description, dtype: object
#
# (2) Remove numbers.
#  0    \niPhone Review A person who uses every major ...
# 1    \nSorry for giving a late feedbackIt has alrea...
# 2                                        \nExcellent\n
# 3    \nI think its better to buy a little expensive...
# 4    \nI used it the worst way one ever  gaming wit...
# Name: Description, dtype: object
# <ipython-input-3-d7f8f7c9187f>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.Description = df.Description.str.replace('[^\w\s]','')
# <ipython-input-3-d7f8f7c9187f>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.Description = df.Description.str.replace('\d+','')
# (3) Remove stopwords by using the stopwords list.
#  0    iPhone Review person uses every major applicat...
# 1    Sorry giving late feedbackIt already past thre...
# 2                                            Excellent
# 3    think better buy little expensive phone great ...
# 4    used worst way one ever gaming charging still ...
# Name: Description, dtype: object
#
# (4) Lowercase all texts.
#  0    iphone review person uses every major applicat...
# 1    sorry giving late feedbackit already past thre...
# 2                                            excellent
# 3    think better buy little expensive phone great ...
# 4    used worst way one ever gaming charging still ...
# Name: Description, dtype: object
#
# (5) Stemming.
#  0    iphone review person uses every major applicat...
# 1    sorry giving late feedbackit already past thre...
# 2                                            excellent
# 3    think better buy little expensive phone great ...
# 4    used worst way one ever gaming charging still ...
# Name: Description, dtype: object
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# (6) Lemmatization.
#  0    iphone review person us every major applicatio...
# 1    sorry giving late feedbackit already past thre...
# 2                                            excellent
# 3    think better buy little expensive phone great ...
# 4    used worst way one ever gaming charging still ...
# Name: Description, dtype: object

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Write your code here

import spacy
nltk.download('punkt')
from spacy import displacy
from nltk import word_tokenize, pos_tag, pos_tag_sents
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize
from collections import Counter
#Tag Parts of Speech of each word in the text
pos = [nltk.pos_tag(word_tokenize(sent)) for sent in df.Description]
print(pos, end="\n\n")
#calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb)
count = [Counter(tag for words, tag in tags) for tags in pos]
print(count, end="\n\n")

import nltk
from nltk import Production, CFG
# grammar
cgrammar = nltk.CFG.fromstring("""
S -> NP VP
VP -> V NP
PP -> P NP
NP -> NP PP | Det N | 'Peter' | 'Denver'
V -> 'prefers'
P -> 'from'
N -> 'flight'
Det -> 'the'
""")
# print grammar
print(cgrammar, end='\n')
sent = ['Peter', 'prefers', 'the', 'flight', 'from', 'Denver']
# Using Chart Parser
cparser = nltk.ChartParser(cgrammar)
for tree in cparser.parse(sent):
  print(tree, end="\n")
# drawing trees
# !pip install svgling==0.3.1
import svgling
svgling.draw_tree(tree)
print("\n")


#3
import en_core_web_sm
nlp = en_core_web_sm.load()
nep = list()
for sentence in df.Description:
  doc=nlp(sentence)
  for X in doc.ents:
    if X.text and X.label_:
      nep.append((X.text, X.label_))
print(nep, end="\n")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [[('iphone', 'NN'), ('review', 'NN'), ('person', 'NN'), ('us', 'PRP'), ('every', 'DT'), ('major', 'JJ'), ('application', 'NN'), ('phone', 'NN'), ('camera', 'NN'), ('note', 'NN'), ('gaming', 'VBG'), ('bingewatching', 'VBG'), ('also', 'RB'), ('want', 'VBP'), ('phone', 'NN'), ('run', 'VB'), ('smoothly', 'RB'), ('least', 'JJS'), ('year', 'NN'), ('may', 'MD'), ('go', 'VB'), ('iphone', 'NN'), ('according', 'VBG'), ('experience', 'NN'), ('would', 'MD'), ('suggest', 'VB'), ('iphone', 'NN'), ('best', 'JJS'), ('choice', 'NN'), ('ive', 'NN'), ('using', 'VBG'), ('android', 'NN'), ('last', 'JJ'), ('year', 'NN'), ('issue', 'NN'), ('facing', 'VBG'), ('phone', 'NN'), ('started', 'VBD'), ('hang', 'NN'), ('within', 'IN'), ('year', 'NN'), ('purchase', 'NN'), ('also', 'RB'), ('began', 'VBD'), ('overheat', 'PRP'), ('would', 'MD'), ('continuously', 'RB'), ('use', 'VB'), ('activity', 'NN'), ('watching', 'VBG'), ('video', 'NN'), ('playing', 'NN'), ('game', 'NN'), ('besides', 'IN'), ('major', 'JJ'), ('issue', 'NN'), ('android', 'IN'), ('phone', 'NN'), ('privacy', 'NN'), ('requires', 'VBZ'), ('data', 'NNS'), ('mobile', 'JJ'), ('device', 'NN'), ('transmitted', 'VBD'), ('google', 'NN'), ('server', 'NN'), ('used', 'VBN'), ('targeted', 'JJ'), ('advertising', 'NN'), ('make', 'VBP'), ('android', 'JJ'), ('le', 'NN'), ('private', 'JJ'), ('mobile', 'NN'), ('operating', 'VBG'), ('system', 'NN'), ('remember', 'VB'), ('whenever', 'WRB'), ('used', 'VBN'), ('search', 'NN'), ('product', 'NN'), ('amazon', 'NN'), ('app', 'IN'), ('phone', 'NN'), ('flooded', 'VBD'), ('ad', 'NN'), ('searched', 'VBN'), ('product', 'NN'), ('get', 'VB'), ('rid', 'JJ'), ('issue', 'NN'), ('thought', 'VBD'), ('give', 'JJ'), ('try', 'NN'), ('io', 'NN'), ('operating', 'VBG'), ('system', 'NN'), ('instead', 'RB'), ('buying', 'VBG'), ('another', 'DT'), ('android', 'JJ'), ('phone', 'NN'), ('apple', 'NN'), ('committed', 'VBD'), ('customer', 'NN'), ('privacy', 'NN'), ('phone', 'NN'), ('also', 'RB'), ('come', 'VBN'), ('powerful', 'JJ'), ('cpucentral', 'JJ'), ('processing', 'NN'), ('unit', 'NN'), ('make', 'VBP'), ('compatible', 'JJ'), ('multitasking', 'NN'), ('long', 'JJ'), ('duration', 'NN'), ('without', 'IN'), ('facing', 'VBG'), ('problem', 'NN'), ('among', 'IN'), ('iphone', 'JJ'), ('model', 'NN'), ('found', 'VBD'), ('iphone', 'RB'), ('budgetfriendly', 'RB'), ('latest', 'JJS'), ('model', 'NN'), ('covered', 'VBD'), ('various', 'JJ'), ('shortcoming', 'VBG'), ('old', 'JJ'), ('model', 'NN'), ('better', 'RBR'), ('performance', 'NN'), ('great', 'JJ'), ('durability', 'NN'), ('dualcamera', 'NN'), ('system', 'NN'), ('many', 'JJ'), ('feature', 'VBP'), ('one', 'CD'), ('important', 'JJ'), ('reason', 'NN'), ('chose', 'VBD'), ('iphone', 'JJ'), ('former', 'JJ'), ('iphones', 'NNS'), ('come', 'VBP'), ('bionic', 'JJ'), ('chip', 'NN'), ('fastest', 'JJS'), ('cpu', 'NN'), ('ever', 'RB'), ('smartphone', 'RB'), ('fall', 'JJ'), ('price', 'NN'), ('range', 'NN'), ('phone', 'NN'), ('powerful', 'JJ'), ('beast', 'NN'), ('perform', 'NN'), ('various', 'JJ'), ('multitasking', 'VBG'), ('without', 'IN'), ('experiencing', 'VBG'), ('lag', 'NN'), ('also', 'RB'), ('best', 'RB'), ('gpugraphical', 'JJ'), ('processing', 'NN'), ('unit', 'NN'), ('allows', 'VBZ'), ('watch', 'VBP'), ('video', 'NN'), ('highest', 'JJS'), ('graphic', 'JJ'), ('remember', 'NN'), ('used', 'VBN'), ('play', 'NN'), ('game', 'NN'), ('old', 'JJ'), ('phone', 'NN'), ('suddenly', 'RB'), ('stop', 'VB'), ('experience', 'NN'), ('new', 'JJ'), ('iphone', 'JJ'), ('term', 'NN'), ('gaming', 'VBG'), ('amazing', 'JJ'), ('whole', 'JJ'), ('game', 'NN'), ('run', 'VB'), ('smoothly', 'RB'), ('without', 'IN'), ('frame', 'NN'), ('drop', 'NN'), ('however', 'RB'), ('would', 'MD'), ('recommend', 'VB'), ('gaming', 'VBG'), ('iphone', 'RB'), ('long', 'JJ'), ('time', 'NN'), ('start', 'NN'), ('overheat', 'NN'), ('additionally', 'RB'), ('io', 'JJ'), ('update', 'JJ'), ('best', 'JJS'), ('update', 'JJ'), ('ever', 'RB'), ('seen', 'VBN'), ('smartphone', 'NN'), ('one', 'CD'), ('favorite', 'JJ'), ('feature',  ...
#
# [Counter({'NN': 216, 'JJ': 76, 'RB': 41, 'VBG': 24, 'VBP': 19, 'VB': 17, 'VBD': 14, 'VBN': 12, 'JJS': 11, 'IN': 11, 'VBZ': 6, 'NNS': 6, 'RBR': 5, 'MD': 4, 'CD': 4, 'DT': 3, 'PRP': 2, 'JJR': 2, 'WRB': 1}), Counter({'NN': 27, 'JJ': 14, 'IN': 6, 'VBP': 6, 'VBG': 4, 'RB': 4, 'VB': 4, 'NNS': 3, 'CD': 2, 'FW': 2, 'VBZ': 2, 'VBD': 1, 'DT': 1, 'JJR': 1, 'WDT': 1, 'JJS': 1}), Counter({'NN': 1}), Counter({'NN': 6, 'JJ': 5, 'RBR': 2, 'VB': 1}), Counter({'NN': 5, 'RB': 3, 'VBG': 3, 'JJ': 3, 'VBN': 1, 'JJS': 1, 'CD': 1, 'IN': 1, 'VBD': 1}), Counter({'NN': 10, 'RB': 4, 'JJ': 4, 'VB': 3, 'VBG': 2, 'IN': 2, 'MD': 1, 'VBP': 1}), Counter({'NN': 185, 'JJ': 80, 'RB': 25, 'VBP': 14, 'VBD': 14, 'VBG': 12, 'VBN': 8, 'NNS': 8, 'IN': 7, 'VB': 4, 'CD': 3, 'JJS': 2, 'MD': 2, 'VBZ': 1, 'RBR': 1, 'NNP': 1, 'DT': 1, 'FW': 1, 'JJR': 1}), Counter({'NN': 201, 'JJ': 104, 'RB': 26, 'VBP': 22, 'VBG': 20, 'VBD': 18, 'IN': 7, 'VB': 6, 'VBN': 6, 'NNS': 4, 'VBZ': 3, 'FW': 2, 'JJS': 2, 'NNP': 1, 'RBR': 1, 'CD': 1, 'CC': 1, 'MD': 1}), Counter({'NN': 156, 'JJ': 82, 'RB': 40, 'VBG': 16, 'VBD': 15, 'VBP': 15, 'VB': 8, 'IN': 7, 'VBN': 7, 'NNS': 6, 'CC': 4, 'CD': 3, 'MD': 2, 'PRP': 2, 'FW': 2, 'VBZ': 2, 'JJR': 2, 'WP': 1, 'NNP': 1}), Counter({'NN': 4, 'RB': 1, 'JJS': 1, 'VBD': 1, 'VBN': 1, 'JJ': 1})]
#
# Grammar with 11 productions (start state = S)
#     S -> NP VP
#     VP -> V NP
#     PP -> P NP
#     NP -> NP PP
#     NP -> Det N
#     NP -> 'Peter'
#     NP -> 'Denver'
#     V -> 'prefers'
#     P -> 'from'
#     N -> 'flight'
#     Det -> 'the'
# (S
#   (NP Peter)
#   (VP
#     (V prefers)
#     (NP (NP (Det the) (N flight)) (PP (P from) (NP Denver)))))
# Collecting svgling==0.3.1
#   Downloading svgling-0.3.1-py3-none-any.whl (21 kB)
# Collecting svgwrite (from svgling==0.3.1)
#   Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.3.1 svgwrite-1.4.3
#
#
# [('smoothly least year', 'DATE'), ('last year', 'DATE'), ('year', 'DATE'), ('google', 'ORG'), ('one', 'CARDINAL'), ('one', 'CARDINAL'), ('one', 'CARDINAL'), ('one', 'CARDINAL'), ('year', 'DATE'), ('three year', 'DATE'), ('one', 'CARDINAL'), ('third', 'ORDINAL'), ('first', 'ORDINAL'), ('last year', 'DATE'), ('almost month', 'DATE'), ('indian', 'NORP'), ('samsung', 'ORG'), ('first', 'ORDINAL'), ('today', 'DATE'), ('today', 'DATE'), ('one', 'CARDINAL'), ('first', 'ORDINAL'), ('enthusiast loyalist decade', 'DATE'), ('samsung', 'ORG'), ('max', 'PERSON'), ('year ago', 'DATE'), ('last day', 'DATE'), ('month year', 'DATE'), ('year', 'DATE'), ('apple', 'ORG'), ('first', 'ORDINAL'), ('one', 'CARDINAL'), ('apps free android', 'ORG'), ('year', 'DATE'), ('apps', 'PERSON'), ('apple keyboard', 'ORG'), ('next morning', 'TIME'), ('late evening', 'TIME'), ('first', 'ORDINAL'), ('decade', 'DATE'), ('year', 'DATE'), ('netflix', 'GPE'), ('samsung', 'ORG'), ('apps easy navigate', 'PERSON'), ('night', 'TIME'), ('hour', 'TIME'), ('last easily hour', 'TIME'), ('google', 'ORG'), ('android', 'ORG')]

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %% [markdown]
# The Constituency Parsing Tree depicts the syntactic arrangement of a sentence through a tree structure, breaking it down into constituent parts like noun phrases and verb phrases. This representation simplifies the comprehension of how words are organized hierarchically within a sentence.
#
# On the other hand, the Dependency Parsing Tree concentrates on the grammatical connections among words within a sentence. It utilizes directed edges to reveal how one word (the head) governs or relies on another (the dependent). This tree offers a more intricate perspective on the grammatical structure of a sentence by highlighting the syntactic roles of words and their interdependencies.
