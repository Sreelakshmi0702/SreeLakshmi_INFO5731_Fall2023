# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreelakshmi0702/SreeLakshmi_INFO5731_Fall2023/blob/main/In_class_exercise_03_10082023_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (due on 11:59 PM 10/08/2023, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand text representation.

# %% [markdown]
# Question 1 (10 points): Describe an interesting text classification or text mining task and explain what kind of features might be useful for you to build the machine learning model. List your features and explain why these features might be helpful. You need to list at least five different types of features.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

Please write you answer here:

Unstructured text is converted into structured data by the process of text mining, sometimes referred to as text analysis, to facilitate analysis.
Natural language processing (NLP) is a technique used in text mining to help computers automatically understand and analyze human language.

Text classification is the process of assigning categories (tags) to unstructured text data. It is simple to organize and organize complex language into meaningful data.
Businesses may rapidly and cheaply get valuable information by utilizing text classification to evaluate a variety of data, including emails and support tickets.

Task:
Text classifiers can automatically identify the goals or purposes underlying a text through the process of "intent detection."
When examining client chats, this can be quite helpful. By sorting through various outbound sales email answers, you might, for instance, separate the prospects who are interested in your product from those who are not or who want to unsubscribe.

1.Linguistic feature extraction
2.Dependency Parse
3.Entity feature
4.Word2vec features
5. Tfidf
# Out:
#   File "<ipython-input-2-881030cf1d5f>", line 15
#     1.Linguistic feature extraction
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# Question 2 (10 points): Write python code to extract these features you discussed above. You can collect a few sample text data for the feature extraction.

# %%
# You code here (Please add comments in the code):

# You code here (Please add comments in the code):

import nltk

from bs4 import BeautifulSoup as bs
import pandas as pd
import requests as rq
import matplotlib.pyplot as plt
import nltk
from wordcloud import WordCloud
from nltk.corpus import stopwords


#collecting sample text data from IMDb "BheemlaNaik movie reviews"

#assigining the URL to a varilable
url = 'https://www.imdb.com/title/tt10733228/reviews/?ref_=tt_ql_urv'

#Creating a data frame with one column to store text of reviews
data_frame = pd.DataFrame(columns=['Review'])
req = rq.get(url).text
soup = bs(req,'html.parser')

#collecting reviews text
review_text = soup.find_all('div', attrs={'class' : 'text show-more__control'})

#creating a empty list
review_list = []
for i in range(len(review_text)):
    review_list.append(review_text[i].get_text())

#assigining list to the data frame
data_frame['Review'] = review_list

data_frame['word_count'] = data_frame['Review'].apply(lambda x: len(str(x).split(" ")))
data_frame[['Review','word_count']].head()
# Out:
#                                               Review  word_count
# 0  The only objective of making such a movie is t...         154
# 1  The weakest part of Gehraiyaan, I thought, was...         168
# 2  Call it an homage or a shameless copy, the mov...          43
# 3  Characters: Not RelatableI am not saying that ...         201
# 4  Seriously This Movie is not Written and Direct...          39

# %%
data_frame['char_count'] = data_frame['Review'].str.len() ## this also includes spaces
data_frame[['Review','char_count']].head()
# Out:
#                                               Review  char_count
# 0  The only objective of making such a movie is t...         890
# 1  The weakest part of Gehraiyaan, I thought, was...        1052
# 2  Call it an homage or a shameless copy, the mov...         244
# 3  Characters: Not RelatableI am not saying that ...        1196
# 4  Seriously This Movie is not Written and Direct...         249

# %%
from nltk.corpus import stopwords

import nltk
nltk.download('stopwords')
stop = stopwords.words('english')

data_frame['stopwords'] = data_frame['Review'].apply(lambda x: len([x for x in x.split() if x in stop]))
data_frame[['Review','stopwords']].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                               Review  stopwords
# 0  The only objective of making such a movie is t...         59
# 1  The weakest part of Gehraiyaan, I thought, was...         60
# 2  Call it an homage or a shameless copy, the mov...         18
# 3  Characters: Not RelatableI am not saying that ...         84
# 4  Seriously This Movie is not Written and Direct...          7

# %%
data_frame['hastags'] = data_frame['Review'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
data_frame[['Review','hastags']].head()
# Out:
#                                               Review  hastags
# 0  The only objective of making such a movie is t...        0
# 1  The weakest part of Gehraiyaan, I thought, was...        0
# 2  Call it an homage or a shameless copy, the mov...        0
# 3  Characters: Not RelatableI am not saying that ...        0
# 4  Seriously This Movie is not Written and Direct...        0

# %%
data_frame['numerics'] = data_frame['Review'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
data_frame[['Review','numerics']].head()
# Out:
#                                               Review  numerics
# 0  The only objective of making such a movie is t...         0
# 1  The weakest part of Gehraiyaan, I thought, was...         0
# 2  Call it an homage or a shameless copy, the mov...         0
# 3  Characters: Not RelatableI am not saying that ...         0
# 4  Seriously This Movie is not Written and Direct...         1

# %%
data_frame['upper'] = data_frame['Review'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
data_frame[['Review','upper']].head()
# Out:
#                                               Review  upper
# 0  The only objective of making such a movie is t...      1
# 1  The weakest part of Gehraiyaan, I thought, was...      1
# 2  Call it an homage or a shameless copy, the mov...      0
# 3  Characters: Not RelatableI am not saying that ...     15
# 4  Seriously This Movie is not Written and Direct...      0

# %% [markdown]
# Question 3 (10 points): Use any of the feature selection methods mentioned in this paper "Deng, X., Li, Y., Weng, J., & Zhang, J. (2019). Feature selection for text classification: A review. Multimedia Tools & Applications, 78(3)."
#
# Select the most important features you extracted above, rank the features based on their importance in the descending order.

# %%
# You code here (Please add comments in the code):

# You code here (Please add comments in the code):
text_classifcation = (data_frame['Review'][1:2]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
text_classifcation.columns =['words', 'tf']
text_classifcation
# Out:
#             words  tf
# 0             the   8
# 1             and   8
# 2               a   5
# 3              of   5
# 4             The   3
# ..            ...  ..
# 126      feelings   1
# 127     struggles   1
# 128  contemporary   1
# 129         done.   1
# 130         down.   1
#
# [131 rows x 2 columns]

# %%
import numpy as np

for i,word in enumerate(text_classifcation['words']):
  text_classifcation.loc[i, 'idf'] = np.log(data_frame.shape[0]/(len(data_frame[data_frame['Review'].str.contains(word)])))

text_classifcations

# %%
text_classifcation['tfidf'] = text_classifcation['tf'] + text_classifcation['idf']
text_classifcation
# Out:
#             words  tf       idf     tfidf
# 0             the   8  0.083382  8.083382
# 1             and   8  0.083382  8.083382
# 2               a   5  0.000000  5.000000
# 3              of   5  0.385662  5.385662
# 4             The   3  0.733969  3.733969
# ..            ...  ..       ...       ...
# 126      feelings   1       NaN       NaN
# 127     struggles   1       NaN       NaN
# 128  contemporary   1       NaN       NaN
# 129         done.   1       NaN       NaN
# 130         down.   1       NaN       NaN
#
# [131 rows x 4 columns]

# %% [markdown]
# Question 4 (10 points): Write python code to rank the text based on text similarity. Based on the text data you used for question 2, design a query to match the most relevant docments. Please use the BERT model to represent both your query and the text data, then calculate the cosine similarity between the query and each text in your data. Rank the similary with descending order.

# %%
# You code here (Please add comments in the code):
